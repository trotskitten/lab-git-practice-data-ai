# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Nicolò Raucci"
reason = "I'm interested in deep diving into the field of data science to master the skills needed to analyze and interpret complex data so I can improve my social research skills"
fun_fact = "When I was a child, I believed in the end of the world that was supposed to happen in 2012 according to the Mayan calendar, so I read a lot of books about mayan culture and I was waiting for Quetzalcoatl to come back to earth"

print(f"Hi! My name is {name}. I’m excited to learn because {reason}. A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Nicolò Raucci. I’m excited to learn because I'm interested in deep diving into the field of data science to master the skills needed to analyze and interpret complex data so I can improve my social research skills. A fun fact about me is: When I was a child, I believed in the end of the world that was supposed to happen in 2012 according to the Mayan calendar, so I read a lot of books about mayan culture and I was waiting for Quetzalcoatl to come back to earth.
